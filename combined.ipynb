# %%
import pandas as pd

# %%
df_tr=pd.read_excel('Transactions.xlsx')
df_cd=pd.read_excel('CustomerDemographics.xlsx')
df_clist=pd.read_excel('Customer_List.xlsx')
df_add=pd.read_excel('Comined_KPMG_Module1.xlsx',sheet_name='Address')

# %%
df_tr.head()
# Out:
#    Unnamed: 0  transaction_id  product_id  customer_id transaction_date  \
# 0           0               1           2         2950       2017-02-25
# 1           1               2           3         3120       2017-05-21
# 2           2               3          37          402       2017-10-16
# 3           3               4          88         3135       2017-08-31
# 4           4               5          78          787       2017-10-01
#
#    online_order order_status           brand product_line product_class  \
# 0             0     Approved           Solex     Standard        medium
# 1             1     Approved   Trek Bicycles     Standard        medium
# 2             0     Approved      OHM Cycles     Standard           low
# 3             0     Approved  Norco Bicycles     Standard        medium
# 4             1     Approved  Giant Bicycles     Standard        medium
#
#   product_size  list_price  standard_cost product_first_sold_date   profit
# ...

# %%
df_cd.head()
# Out:
#    Unnamed: 0  customer_id first_name  last_name  gender  \
# 0           0            1    Laraine  Medendorp  Female
# 1           1            2        Eli    Bockman    Male
# 2           2            3      Arlin     Dearle    Male
# 3           8            9       Mala       Lind  Female
# 4           9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   97 1973-03-10
# 4                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 3  Business Systems Development Analyst           Argiculture
# ...

# %%
df_add.head()
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
# 2            4   0 Holy Cross Court      4211   QLD  Australia
# 3            5  17979 Del Mar Point      2448   NSW  Australia
# 4            6     9 Oakridge Court      3216   VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
df_clist.head()
# Out:
#    Unnamed: 0 first_name  last_name  gender  \
# 0           0    Chickie    Brister    Male
# 1           1      Morly     Genery    Male
# 2           2    Ardelis  Forrester  Female
# 3           3     Lucine      Stutt  Female
# 4           4    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator  ... postcode  \
# 0         Manufacturing      Mass Customer                  N  ...     4500
# ...

# %%
a=[]
a=[df_cd.shape,df_add.shape,df_clist.shape,df_tr.shape]
a
# Out:
# [(2862, 13), (3999, 6), (715, 23), (19273, 15)]

# %%
df_tr=pd.merge(df_tr,df_cd,on='customer_id')
df_tr.head()
# Out:
#    Unnamed: 0_x  transaction_id  product_id  customer_id transaction_date  \
# 0             0               1           2         2950       2017-02-25
# 1         11064           11065           1         2950       2017-10-16
# 2         18922           18923          62         2950       2017-04-26
# 3             1               2           3         3120       2017-05-21
# 4          6861            6862           4         3120       2017-10-05
#
#    online_order order_status           brand product_line product_class  ...  \
# 0             0     Approved           Solex     Standard        medium  ...
# 1             0     Approved  Giant Bicycles     Standard        medium  ...
# 2             0     Approved           Solex     Standard        medium  ...
# 3             1     Approved   Trek Bicycles     Standard        medium  ...
# 4             0     Approved  Giant Bicycles     Standard          high  ...
#
# ...

# %%
df_tr['profit'].head()
# Out:
# 0      17.87
# 1     448.68
# 2     179.44
# 3    1702.55
# 4     451.65
# Name: profit, dtype: float64

# %%
df_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13922 entries, 0 to 13921
# Data columns (total 27 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0_x                         13922 non-null  int64
#  1   transaction_id                       13922 non-null  int64
#  2   product_id                           13922 non-null  int64
#  3   customer_id                          13922 non-null  int64
#  4   transaction_date                     13922 non-null  datetime64[ns]
#  5   online_order                         13922 non-null  int64
#  6   order_status                         13922 non-null  object
#  7   brand                                13922 non-null  object
#  8   product_line                         13922 non-null  object
#  9   product_class                        13922 non-null  object
#  10  product_size                         13922 non-null  object
# ...

# %%
print(df_tr.isnull().sum())
# Out:
# Unnamed: 0_x                             0
# transaction_id                           0
# product_id                               0
# customer_id                              0
# transaction_date                         0
# online_order                             0
# order_status                             0
# brand                                    0
# product_line                             0
# product_class                            0
# product_size                             0
# list_price                               0
# standard_cost                            0
# product_first_sold_date                  0
# profit                                   0
# Unnamed: 0_y                             0
# first_name                               0
# last_name                              422
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                                0
# ...

# %%
df_tr=pd.merge(df_tr,df_add,on='customer_id')
df_tr.head()
# Out:
#    Unnamed: 0_x  transaction_id  product_id  customer_id transaction_date  \
# 0             0               1           2         2950       2017-02-25
# 1         11064           11065           1         2950       2017-10-16
# 2         18922           18923          62         2950       2017-04-26
# 3             1               2           3         3120       2017-05-21
# 4          6861            6862           4         3120       2017-10-05
#
#    online_order order_status           brand product_line product_class  ...  \
# 0             0     Approved           Solex     Standard        medium  ...
# 1             0     Approved  Giant Bicycles     Standard        medium  ...
# 2             0     Approved           Solex     Standard        medium  ...
# 3             1     Approved   Trek Bicycles     Standard        medium  ...
# 4             0     Approved  Giant Bicycles     Standard          high  ...
#
# ...

# %%
df_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13910 entries, 0 to 13909
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0_x                         13910 non-null  int64
#  1   transaction_id                       13910 non-null  int64
#  2   product_id                           13910 non-null  int64
#  3   customer_id                          13910 non-null  int64
#  4   transaction_date                     13910 non-null  datetime64[ns]
#  5   online_order                         13910 non-null  int64
#  6   order_status                         13910 non-null  object
#  7   brand                                13910 non-null  object
#  8   product_line                         13910 non-null  object
#  9   product_class                        13910 non-null  object
#  10  product_size                         13910 non-null  object
# ...

# %%
df_tr.shape
# Out:
# (13910, 32)

# %%
df_tr.to_excel('.xlsx')

# %%
df_tr.shape
# Out:
# (13910, 32)
